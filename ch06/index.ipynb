# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# 設定隨機種子，方便重現
np.random.seed(42)
random.seed(42)

n = 200  # 紀錄數

# 生成訂單編號，格式為 ORD0001, ORD0002, ...
order_ids = [f"ORD{str(i+1).zfill(4)}" for i in range(n)]

# 客戶名稱列表（可自由調整）
customer_names = ["王小明", "李小華", "陳大文", "林小美",None, "張大偉", "劉德華", "周杰倫", "鄧紫棋", "蔡依林", "郭富城"]
customers = [random.choice(customer_names) for _ in range(n)]

# 生成隨機訂單日期：介於 2023-01-01 與 2023-12-31 之間
start_date = datetime.strptime("2023-01-01", "%Y-%m-%d")
end_date = datetime.strptime("2023-12-31", "%Y-%m-%d")
date_range = (end_date - start_date).days
order_dates = [start_date + timedelta(days=random.randint(0, date_range)) for _ in range(n)]
order_dates = [d.strftime("%Y-%m-%d") for d in order_dates]

# 產品名稱列表
products = ["筆記型電腦", "手機", "平板", None, "耳機", "鍵盤", "滑鼠", "顯示器", "打印機", "相機", "智慧手錶"]
product_choices = [random.choice(products) for _ in range(n)]

# 隨機數量：介於 1 到 10
quantities = np.random.randint(1, 11, n)

# 單價：介於 1000 到 10000 之間，取小數點後 2 位
unit_prices = [round(random.uniform(1000, 10000), 2) for _ in range(n)]

# 總價 = 數量 * 單價（取小數點後 2 位）
total_prices = [round(q * p, 2) for q, p in zip(quantities, unit_prices)]

# 付款方式列表
payment_methods = ["信用卡", "現金",None, "轉帳", "電子支付"]
payment_choices = [random.choice(payment_methods) for _ in range(n)]

# 訂單狀態列表
order_statuses = ["已出貨", "處理中", None,"已取消", "退貨"]
status_choices = [random.choice(order_statuses) for _ in range(n)]

# 備註：隨機選擇，部分可能為缺失值 (None)
remarks_options = ["", "急件", "贈品包裝", None, "需揀貨", "加急處理"]
remarks = [random.choice(remarks_options) for _ in range(n)]

# 建立 DataFrame
df = pd.DataFrame({
    "訂單編號": order_ids,
    "客戶名稱": customers,
    "訂單日期": order_dates,
    "產品": product_choices,
    "數量": quantities,
    "單價": unit_prices,
    "總價": total_prices,
    "付款方式": payment_choices,
    "訂單狀態": status_choices,
    "備註": remarks
})


df.head(100)
# Out:
#        訂單編號  客戶名稱        訂單日期     產品  數量       單價        總價  付款方式 訂單狀態    備註
# 0   ORD0001   郭富城  2023-08-05     鍵盤   7  2582.98  18080.86  None  已取消  加急處理
# 1   ORD0002   李小華  2023-04-19   None   4  9621.69  38486.76   信用卡  已取消  加急處理
# 2   ORD0003   王小明  2023-10-04   智慧手錶   8  5661.62  45292.96    現金  已取消  加急處理
# 3   ORD0004  None  2023-12-20   智慧手錶   5  1451.97   7259.85  None  處理中  贈品包裝
# 4   ORD0005   林小美  2023-04-13     耳機   7  3242.78  22699.46    現金  已取消   需揀貨
# ..      ...   ...         ...    ...  ..      ...       ...   ...  ...   ...
# 95  ORD0096   王小明  2023-07-14  筆記型電腦  10  2794.25  27942.50    現金  已取消  贈品包裝
# 96  ORD0097   林小美  2023-01-02     手機   9  1183.42  10650.78   信用卡  處理中    急件
# 97  ORD0098   王小明  2023-07-19     相機   7  2371.44  16600.08   信用卡  處理中   需揀貨
# 98  ORD0099   張大偉  2023-05-16     滑鼠   9  2135.99  19223.91    現金   退貨
# 99  ORD0100   劉德華  2023-08-21     鍵盤   8  7025.13  56201.04  None  已取消  贈品包裝
#
# [100 rows x 10 columns]

# %%
#刪除遺失值 
results = df.dropna()

results = results.reset_index(drop=True)

results.head()
# Out:
#       訂單編號 客戶名稱        訂單日期     產品  數量       單價        總價  付款方式 訂單狀態    備註
# 0  ORD0003  王小明  2023-10-04   智慧手錶   8  5661.62  45292.96    現金  已取消  加急處理
# 1  ORD0005  林小美  2023-04-13     耳機   7  3242.78  22699.46    現金  已取消   需揀貨
# 2  ORD0007  陳大文  2023-07-24    顯示器   3  5108.16  15324.48    現金  處理中  加急處理
# 3  ORD0009  郭富城  2023-11-29  筆記型電腦   8  7008.20  56065.60   信用卡  處理中
# 4  ORD0010  鄧紫棋  2023-07-11     手機   5  9891.03  49455.15  電子支付   退貨  加急處理

# %%
#填充遺失值
results = df

results["客戶名稱"] = results["客戶名稱"].fillna("其它")

print("出現最多",df["產品"].value_counts().idxmax())

results["產品"] = results["產品"].fillna(df["產品"].value_counts().idxmax())

print("出現最少",df["付款方式"].value_counts().idxmin())

results["付款方式"] = results["付款方式"].fillna(df["付款方式"].value_counts().idxmin())

results["訂單狀態"] = results["訂單狀態"].fillna("現金")

results["數量"] = results["數量"].fillna(results["數量"].mean())

results.head(100)
# Out:
# 出現最多 智慧手錶
# 出現最少 現金
#        訂單編號 客戶名稱        訂單日期     產品  數量       單價        總價 付款方式 訂單狀態    備註
# 0   ORD0001  郭富城  2023-08-05     鍵盤   7  2582.98  18080.86   現金  已取消  加急處理
# 1   ORD0002  李小華  2023-04-19   智慧手錶   4  9621.69  38486.76  信用卡  已取消  加急處理
# 2   ORD0003  王小明  2023-10-04   智慧手錶   8  5661.62  45292.96   現金  已取消  加急處理
# 3   ORD0004   其它  2023-12-20   智慧手錶   5  1451.97   7259.85   現金  處理中  贈品包裝
# 4   ORD0005  林小美  2023-04-13     耳機   7  3242.78  22699.46   現金  已取消   需揀貨
# ..      ...  ...         ...    ...  ..      ...       ...  ...  ...   ...
# 95  ORD0096  王小明  2023-07-14  筆記型電腦  10  2794.25  27942.50   現金  已取消  贈品包裝
# 96  ORD0097  林小美  2023-01-02     手機   9  1183.42  10650.78  信用卡  處理中    急件
# 97  ORD0098  王小明  2023-07-19     相機   7  2371.44  16600.08  信用卡  處理中   需揀貨
# 98  ORD0099  張大偉  2023-05-16     滑鼠   9  2135.99  19223.91   現金   退貨
# 99  ORD0100  劉德華  2023-08-21     鍵盤   8  7025.13  56201.04   現金  已取消  贈品包裝
#
# [100 rows x 10 columns]

# %%
results = df["客戶名稱"].duplicated() 
results.head(100)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: 客戶名稱, Length: 100, dtype: bool

# %%
results = df["客戶名稱"].value_counts() 
results.head(100)
# Out:
# 客戶名稱
# 李小華    24
# 郭富城    22
# 鄧紫棋    22
# 林小美    21
# 其它     19
# 陳大文    18
# 蔡依林    16
# 張大偉    16
# 王小明    15
# 劉德華    15
# 周杰倫    12
# Name: count, dtype: int64

# %%
results = df.drop_duplicates(["客戶名稱"])
results = results.reset_index(drop=True)
results.head(100)
# Out:
#        訂單編號 客戶名稱        訂單日期    產品  數量       單價        總價  付款方式 訂單狀態    備註
# 0   ORD0001  郭富城  2023-08-05    鍵盤   7  2582.98  18080.86    現金  已取消  加急處理
# 1   ORD0002  李小華  2023-04-19  智慧手錶   4  9621.69  38486.76   信用卡  已取消  加急處理
# 2   ORD0003  王小明  2023-10-04  智慧手錶   8  5661.62  45292.96    現金  已取消  加急處理
# 3   ORD0004   其它  2023-12-20  智慧手錶   5  1451.97   7259.85    現金  處理中  贈品包裝
# 4   ORD0005  林小美  2023-04-13    耳機   7  3242.78  22699.46    現金  已取消   需揀貨
# 5   ORD0007  陳大文  2023-07-24   顯示器   3  5108.16  15324.48    現金  處理中  加急處理
# 6   ORD0010  鄧紫棋  2023-07-11    手機   5  9891.03  49455.15  電子支付   退貨  加急處理
# 7   ORD0012  蔡依林  2023-09-22    滑鼠   8  9550.36  76402.88    現金  處理中  None
# 8   ORD0013  劉德華  2023-08-20    耳機   8  9022.83  72182.64   信用卡  已出貨
# 9   ORD0028  周杰倫  2023-11-20    平板   3  3471.38  10414.14   信用卡  已取消    急件
# 10  ORD0034  張大偉  2023-02-06    平板   3  2245.37   6736.11    轉帳  已取消

# %%
#  取代replace

df["客戶名稱"] = df["客戶名稱"].replace(["其它",None],"遺失客戶")
df.head(100)
# Out:
#        訂單編號  客戶名稱        訂單日期     產品  數量       單價        總價 付款方式 訂單狀態    備註
# 0   ORD0001   郭富城  2023-08-05     鍵盤   7  2582.98  18080.86   現金  已取消  加急處理
# 1   ORD0002   李小華  2023-04-19   智慧手錶   4  9621.69  38486.76  信用卡  已取消  加急處理
# 2   ORD0003   王小明  2023-10-04   智慧手錶   8  5661.62  45292.96   現金  已取消  加急處理
# 3   ORD0004  遺失客戶  2023-12-20   智慧手錶   5  1451.97   7259.85   現金  處理中  贈品包裝
# 4   ORD0005   林小美  2023-04-13     耳機   7  3242.78  22699.46   現金  已取消   需揀貨
# ..      ...   ...         ...    ...  ..      ...       ...  ...  ...   ...
# 95  ORD0096   王小明  2023-07-14  筆記型電腦  10  2794.25  27942.50   現金  已取消  贈品包裝
# 96  ORD0097   林小美  2023-01-02     手機   9  1183.42  10650.78  信用卡  處理中    急件
# 97  ORD0098   王小明  2023-07-19     相機   7  2371.44  16600.08  信用卡  處理中   需揀貨
# 98  ORD0099   張大偉  2023-05-16     滑鼠   9  2135.99  19223.91   現金   退貨
# 99  ORD0100   劉德華  2023-08-21     鍵盤   8  7025.13  56201.04   現金  已取消  贈品包裝
#
# [100 rows x 10 columns]

# %%
results = df.groupby(by=["客戶名稱"]).sum().reset_index() 

results.head()
# Out:
#   客戶名稱                                               訂單編號  \
# 0  劉德華  ORD0013ORD0026ORD0033ORD0041ORD0051ORD0068ORD0...
# 1  周杰倫  ORD0028ORD0048ORD0070ORD0088ORD0108ORD0111ORD0...
# 2  張大偉  ORD0034ORD0038ORD0043ORD0044ORD0057ORD0072ORD0...
# 3  李小華  ORD0002ORD0008ORD0011ORD0016ORD0039ORD0040ORD0...
# 4  林小美  ORD0005ORD0006ORD0017ORD0018ORD0023ORD0027ORD0...
#
#                                                 訂單日期  \
# 0  2023-08-202023-02-062023-06-192023-10-042023-0...
# 1  2023-11-202023-07-282023-10-022023-03-272023-0...
# 2  2023-02-062023-12-092023-10-202023-10-232023-0...
# 3  2023-04-192023-12-102023-08-132023-04-262023-0...
# 4  2023-04-132023-06-092023-02-022023-06-232023-1...
#
#                                                   產品   數量         單價  \
# 0             耳機手機打印機鍵盤平板智慧手錶鍵盤鍵盤耳機手機鍵盤打印機滑鼠智慧手錶智慧手錶   97   94584.25
# 1                 平板打印機顯示器打印機智慧手錶滑鼠耳機智慧手錶顯示器智慧手錶相機平板   55   51445.02
# 2     平板耳機智慧手錶智慧手錶平板耳機智慧手錶筆記型電腦耳機滑鼠手機相機滑鼠相機智慧手錶筆記型電腦   94   76842.93
# 3  智慧手錶耳機智慧手錶鍵盤鍵盤筆記型電腦智慧手錶相機智慧手錶智慧手錶滑鼠顯示器手機滑鼠打印機智...  134  125320.98
# 4  耳機打印機平板智慧手錶滑鼠手機筆記型電腦滑鼠平板筆記型電腦智慧手錶滑鼠平板手機相機滑鼠智慧手...  137  112994.44
#
#           總價                                               付款方式  \
# 0  642339.84               信用卡現金轉帳現金電子支付現金現金現金現金現金信用卡現金轉帳信用卡信用卡
# 1  231423.90                 信用卡電子支付現金電子支付轉帳電子支付現金現金現金現金電子支付信用卡
# 2  448024.63            轉帳現金現金信用卡轉帳信用卡信用卡轉帳現金現金信用卡現金電子支付轉帳現金信用卡
# 3  675754.63  信用卡現金現金現金現金電子支付信用卡現金轉帳電子支付現金信用卡現金電子支付電子支付現金轉帳現...
# 4  678723.15  現金現金現金轉帳轉帳現金信用卡電子支付信用卡現金轉帳現金現金信用卡現金轉帳電子支付電子支付現...
#
#                                                 訂單狀態  \
# 0          已出貨已取消已取消已取消退貨已取消已出貨已取消處理中現金處理中已出貨退貨現金處理中
# 1                       已取消已取消現金現金退貨退貨現金現金退貨退貨處理中已出貨
# 2           已取消退貨現金已取消退貨已取消已取消退貨現金退貨已出貨已出貨處理中已取消退貨現金
# 3  已取消已取消退貨現金已取消處理中已出貨處理中退貨處理中現金退貨處理中處理中已取消已取消已取消...
# 4  已取消退貨退貨現金退貨退貨處理中已出貨已出貨現金已出貨已取消現金處理中處理中退貨現金已取消現...
#
#                                                   備註
# 0           加急處理加急處理需揀貨急件贈品包裝急件加急處理需揀貨需揀貨加急處理需揀貨贈品包裝
# 1                        急件加急處理贈品包裝需揀貨贈品包裝急件加急處理贈品包裝
# 2                                  加急處理需揀貨急件急件急件加急處理
# 3  加急處理贈品包裝急件贈品包裝贈品包裝加急處理急件贈品包裝加急處理急件贈品包裝需揀貨加急處理需...
# 4        需揀貨需揀貨急件加急處理急件贈品包裝急件加急處理急件需揀貨急件需揀貨加急處理需揀貨急件

# %%
results = df[["客戶名稱","總價"]].groupby(by=["客戶名稱"]).mean().reset_index() 

results.head()
# Out:
#   客戶名稱            總價
# 0  劉德華  42822.656000
# 1  周杰倫  19285.325000
# 2  張大偉  28001.539375
# 3  李小華  28156.442917
# 4  林小美  32320.150000

# %%
results = df.groupby(by=["客戶名稱"]).agg({
    "總價":['sum',"mean"],
    "數量":['sum'],
})
results.head(100000)
# Out:
#              總價                 數量
#             sum          mean  sum
# 客戶名稱
# 劉德華   642339.84  42822.656000   97
# 周杰倫   231423.90  19285.325000   55
# 張大偉   448024.63  28001.539375   94
# 李小華   675754.63  28156.442917  134
# 林小美   678723.15  32320.150000  137
# 王小明   354925.61  23661.707333   76
# 蔡依林   605126.72  37820.420000   97
# 遺失客戶  595736.23  31354.538421  112
# 郭富城   685895.46  31177.066364  121
# 鄧紫棋   748605.63  34027.528636  124
# 陳大文   313514.64  17417.480000   65

# %%
results = df.groupby(by=['客戶名稱']).value_counts()

print(results.to_string())
# Out:
# 客戶名稱  訂單編號     訂單日期        產品     數量  單價       總價        付款方式  訂單狀態  備註
# 劉德華   ORD0013  2023-08-20  耳機     8   9022.83  72182.64  信用卡   已出貨           1
#       ORD0033  2023-06-19  打印機    5   5861.37  29306.85  轉帳    已取消           1
#       ORD0041  2023-10-04  鍵盤     9   4741.97  42677.73  現金    已取消   加急處理    1
#       ORD0051  2023-02-19  平板     3   4165.83  12497.49  電子支付  退貨    加急處理    1
#       ORD0068  2023-04-09  智慧手錶   8   2148.65  17189.20  現金    已取消   需揀貨     1
#       ORD0089  2023-07-28  鍵盤     8   9999.17  79993.36  現金    已出貨   急件      1
#       ORD0100  2023-08-21  鍵盤     8   7025.13  56201.04  現金    已取消   贈品包裝    1
#       ORD0109  2023-06-01  耳機     6   8373.71  50242.26  現金    處理中   急件      1
#       ORD0120  2023-09-15  手機     9   6645.18  59806.62  現金    現金    加急處理    1
#       ORD0122  2023-03-22  鍵盤     10  7952.33  79523.30  信用卡   處理中   需揀貨     1
#       ORD0135  2023-05-07  打印機    2   1949.85  3899.70   現金    已出貨   需揀貨     1
#       ORD0138  2023-01-21  滑鼠     5   8458.37  42291.85  轉帳    退貨    加急處理    1
#       ORD0139  2023-11-14  智慧手錶   6   7365.78  44194.68  信用卡   現金    需揀貨     1
#       ORD0155  2023-12-10  智慧手錶   9   5182.38  46641.42  信用卡   處理中   贈品包裝    1
# 周杰倫   ORD0028  2023-11-20  平板     3   3471.38  10414.14  信用卡   已取消   急件      1
#       ORD0048  2023-07-28  打印機    4   7890.35  31561.40  電子支付  已取消   加急處理    1
#       ORD0070  2023-10-02  顯示器    9   1242.70  11184.30  現金    現金    贈品包裝    1
#       ORD0088  2023-03-27  打印機    1   5854.77  5854.77   電子支付  現金    需揀貨     1
#       ORD0108  2023-04-08  智慧手錶   8   2030.80  16246.40  轉帳    退貨            1
#       ORD0111  2023-01-30  滑鼠     1   1972.89  1972.89   電子支付  退貨    贈品包裝    1
#       ORD0157  2023-06-03  顯示器    1   4410.90  4410.90   現金    退貨    急件      1
#       ORD0178  2023-08-13  智慧手錶   2   2994.37  5988.74   現金    退貨    加急處理    1
#       ORD0195  2023-10-11  平板     6   2666.35  15998.10  信用卡   已出貨   贈品包裝    1
# 張大偉   ORD0034  2023-02-06  平板     3   2245.37  6736.11   轉帳    已取消           1
#       ORD0043  2023-10-20  智慧手錶   10  4781.29  47812.90  現金    現金    加急處理    1
#       ORD0044  2023-10-23  智慧手錶   9   9143.55  82291.95  信用卡   已取消   需揀貨     1
#       ORD0057  2023-08-28  平板     2   5915.19  11830.38  轉帳    退貨            1
#       ORD0074  2023-04-04  智慧手錶   5   6784.75  33923.75  信用卡   已取消   急件      1
#       ORD0075  2023-05-23  筆記型電腦  8   2221.30  17770.40  轉帳    退貨            1
#       ORD0095  2023-03-26  耳機     7   9546.51  66825.57  現金    現金    急件      1
#       ORD0099  2023-05-16  滑鼠     9   2135.99  19223.91  現金    退貨            1
#       ORD0105  2023-12-05  手機     8   2510.10  20080.80  信用卡   已出貨   急件      1
#       ORD0123  2023-01-30  相機     3   8652.64  25957.92  現金    已出貨           1
#       ORD0177  2023-03-22  智慧手錶   1   1837.48  1837.48   現金    退貨            1
#       ORD0181  2023-06-04  筆記型電腦  7   6234.00  43638.00  信用卡   現金    加急處理    1
# 李小華   ORD0002  2023-04-19  智慧手錶   4   9621.69  38486.76  信用卡   已取消   加急處理    1
#       ORD0008  2023-12-10  耳機     7   8212.75  57489.25  現金    已取消   贈品包裝    1
#       ORD0011  2023-08-13  智慧手錶   4   6359.07  25436.28  現金    退貨    急件      1
#       ORD0016  2023-04-26  鍵盤     5   5543.00  27715.00  現金    現金    贈品包裝    1
#       ORD0040  2023-04-20  筆記型電腦  4   5883.50  23534.00  電子支付  處理中   贈品包裝    1
#       ORD0042  2023-03-09  智慧手錶   2   2861.51  5723.02   信用卡   已出貨   加急處理    1
#       ORD0052  2023-12-04  智慧手錶   1   7781.28  7781.28   轉帳    退貨            1
#       ORD0060  2023-12-01  智慧手錶   10  2974.79  29747.90  電子支付  處理中   急件      1
#       ORD0065  2023-06-23  滑鼠     2   4638.85  9277.70   現金    現金            1
#       ORD0067  2023-05-08  顯示器    4   5206.51  20826.04  信用卡   退貨    贈品包裝    1
#       ORD0081  2023-02-20  手機     7   7851.07  54957.49  現金    處理中   加急處理    1
#       ORD0102  2023-08-05  滑鼠     1   2961.68  2961.68   電子支付  處理中   急件      1
#       ORD0128  2023-11-01  打印機    5   4124.83  20624.15  電子支付  已取消   贈品包裝    1
#       ORD0130  2023-12-12  智慧手錶   7   4335.14  30345.98  現金    已取消   需揀貨     1
#       ORD0137  2023-11-01  智慧手錶   9   6720.27  60482.43  轉帳    已取消   加急處理    1
#       ORD0153  2023-07-22  相機     6   8934.68  53608.08  信用卡   退貨            1
#       ORD0163  2023-11-15  顯示器    9   4063.05  36567.45  電子支付  已取消   需揀貨     1
#       ORD0180  2023-12-27  筆記型電腦  6   3755.85  22535.10  轉帳    處理中   需揀貨     1
#       ORD0187  2023-10-11  滑鼠     5   7325.69  36628.45  電子支付  已出貨   贈品包裝    1
# 林小美   ORD0005  2023-04-13  耳機     7   3242.78  22699.46  現金    已取消   需揀貨     1
#       ORD0017  2023-02-02  平板     2   8475.12  16950.24  現金    退貨    需揀貨     1
#       ORD0018  2023-06-23  智慧手錶   8   5930.85  47446.80  轉帳    現金    急件      1
#       ORD0023  2023-10-29  滑鼠     10  3225.16  32251.60  轉帳    退貨    加急處理    1
#       ORD0027  2023-12-29  手機     10  6640.74  66407.40  現金    退貨            1
#       ORD0037  2023-05-23  筆記型電腦  9   7357.77  66219.93  信用卡   處理中   急件      1
#       ORD0059  2023-12-11  滑鼠     6   2984.85  17909.10  電子支付  已出貨   贈品包裝    1
#       ORD0063  2023-02-01  平板     2   4025.17  8050.34   信用卡   已出貨   急件      1
#       ORD0066  2023-02-25  筆記型電腦  10  2485.40  24854.00  現金    現金    加急處理    1
#       ORD0086  2023-02-17  滑鼠     8   1737.16  13897.28  現金    已取消   急件      1
#       ORD0093  2023-07-25  平板     5   6865.79  34328.95  現金    現金    需揀貨     1
#       ORD0097  2023-01-02  手機     9   1183.42  10650.78  信用卡   處理中   急件      1
#       ORD0103  2023-12-23  相機     7   7295.18  51066.26  現金    處理中   需揀貨     1
#       ORD0106  2023-09-07  滑鼠     5   6465.23  32326.15  轉帳    退貨            1
#       ORD0115  2023-06-10  智慧手錶   1   9623.56  9623.56   電子支付  現金            1
#       ORD0124  2023-09-18  鍵盤     7   6403.70  44825.90  電子支付  已取消   加急處理    1
#       ORD0169  2023-09-17  智慧手錶   7   1770.52  12393.64  現金    現金    需揀貨     1
#       ORD0185  2023-01-05  手機     3   7713.42  23140.26  現金    已出貨   急件      1
# 王小明   ORD0003  2023-10-04  智慧手錶   8   5661.62  45292.96  現金    已取消   加急處理    1
#       ORD0014  2023-03-03  筆記型電腦  3   6513.87  19541.61  信用卡   現金    需揀貨     1
#       ORD0015  2023-05-07  筆記型電腦  6   7473.47  44840.82  電子支付  已取消   需揀貨     1
#       ORD0021  2023-10-11  顯示器    5   5272.07  26360.35  電子支付  現金    加急處理    1
#       ORD0031  2023-02-04  鍵盤     9   3445.44  31008.96  信用卡   退貨    贈品包裝    1
#       ORD0047  2023-08-31  鍵盤     2   8710.59  17421.18  電子支付  處理中   加急處理    1
#       ORD0096  2023-07-14  筆記型電腦  10  2794.25  27942.50  現金    已取消   贈品包裝    1
#       ORD0098  2023-07-19  相機     7   2371.44  16600.08  信用卡   處理中   需揀貨     1
#       ORD0129  2023-02-04  耳機     7   4855.40  33987.80  信用卡   現金    需揀貨     1
#       ORD0158  2023-08-23  顯示器    3   1258.30  3774.90   現金    現金            1
#       ORD0175  2023-07-09  智慧手錶   8   5417.39  43339.12  現金    退貨            1
#       ORD0179  2023-10-06  平板     2   7226.08  14452.16  轉帳    現金    加急處理    1
# 蔡依林   ORD0020  2023-10-29  平板     2   7692.90  15385.80  信用卡   現金            1
#       ORD0029  2023-01-31  打印機    7   1697.35  11881.45  現金    現金            1
#       ORD0056  2023-07-30  筆記型電腦  4   7727.64  30910.56  電子支付  已出貨   贈品包裝    1
#       ORD0058  2023-01-28  鍵盤     6   6429.27  38575.62  現金    已取消   加急處理    1
#       ORD0082  2023-01-26  耳機     9   4412.14  39709.26  現金    已出貨   需揀貨     1
#       ORD0104  2023-10-12  打印機    7   7902.08  55314.56  轉帳    處理中   贈品包裝    1
#       ORD0119  2023-09-02  滑鼠     7   7215.53  50508.71  電子支付  已取消   急件      1
#       ORD0136  2023-10-24  平板     10  9647.09  96470.90  電子支付  處理中           1
#       ORD0140  2023-02-11  滑鼠     4   4919.38  19677.52  轉帳    退貨    贈品包裝    1
#       ORD0168  2023-04-20  打印機    4   9532.56  38130.24  電子支付  已出貨   需揀貨     1
#       ORD0176  2023-05-26  耳機     1   8136.40  8136.40   電子支付  現金    加急處理    1
#       ORD0200  2023-04-18  智慧手錶   6   5721.73  34330.38  現金    現金    加急處理    1
# 遺失客戶  ORD0004  2023-12-20  智慧手錶   5   1451.97  7259.85   現金    處理中   贈品包裝    1
#       ORD0030  2023-04-28  筆記型電腦  4   3571.55  14286.20  轉帳    現金            1
#       ORD0035  2023-09-21  滑鼠     7   3081.35  21569.45  信用卡   現金    急件      1
#       ORD0046  2023-05-05  手機     5   7259.71  36298.55  轉帳    已取消   需揀貨     1
#       ORD0054  2023-07-01  平板     2   9580.87  19161.74  轉帳    已出貨   需揀貨     1
#       ORD0064  2023-07-26  手機     10  7112.28  71122.80  現金    已取消   贈品包裝    1
#       ORD0069  2023-04-08  智慧手錶   7   6600.31  46202.17  現金    已出貨   加急處理    1
#       ORD0078  2023-02-08  滑鼠     9   4411.93  39707.37  轉帳    已出貨   加急處理    1
#       ORD0090  2023-09-06  筆記型電腦  3   4149.64  12448.92  轉帳    已出貨           1
#       ORD0101  2023-05-27  鍵盤     2   6075.73  12151.46  電子支付  退貨    急件      1
#       ORD0113  2023-10-05  打印機    5   3807.62  19038.10  轉帳    處理中   需揀貨     1
#       ORD0118  2023-10-27  鍵盤     7   1683.97  11787.79  現金    已出貨           1
#       ORD0143  2023-10-26  相機     9   3430.74  30876.66  現金    已出貨           1
#       ORD0154  2023-03-09  相機     8   3194.77  25558.16  轉帳    現金            1
#       ORD0159  2023-06-11  顯示器    10  8658.58  86585.80  信用卡   處理中   急件      1
#       ORD0165  2023-02-21  智慧手錶   1   7310.65  7310.65   轉帳    退貨    加急處理    1
#       ORD0182  2023-11-10  智慧手錶   5   5259.34  26296.70  信用卡   已取消   急件      1
#       ORD0198  2023-05-25  手機     4   7521.27  30085.08  現金    已出貨   贈品包裝    1
# 郭富城   ORD0001  2023-08-05  鍵盤     7   2582.98  18080.86  現金    已取消   加急處理    1
#       ORD0009  2023-11-29  筆記型電腦  8   7008.20  56065.60  信用卡   處理中           1
#       ORD0024  2023-04-23  打印機    6   6738.95  40433.70  轉帳    已取消   贈品包裝    1
#       ORD0071  2023-08-18  鍵盤     8   4546.18  36369.44  電子支付  退貨            1
#       ORD0077  2023-05-08  智慧手錶   9   1452.56  13073.04  電子支付  退貨            1
#       ORD0079  2023-08-15  鍵盤     1   2904.94  2904.94   現金    處理中   急件      1
#       ORD0080  2023-10-09  耳機     9   3941.61  35474.49  信用卡   現金    加急處理    1
#       ORD0083  2023-11-30  鍵盤     8   7768.09  62144.72  現金    已取消           1
#       ORD0091  2023-09-04  手機     3   6851.30  20553.90  信用卡   現金    需揀貨     1
#       ORD0094  2023-01-31  相機     10  7788.10  77881.00  現金    現金    急件      1
#       ORD0107  2023-03-21  相機     3   7731.33  23193.99  現金    已取消   加急處理    1
#       ORD0110  2023-04-22  筆記型電腦  3   9682.49  29047.47  電子支付  已取消           1
#       ORD0134  2023-10-19  耳機     6   8400.98  50405.88  現金    已取消   急件      1
#       ORD0148  2023-04-15  筆記型電腦  9   7579.24  68213.16  轉帳    已出貨   加急處理    1
#       ORD0151  2023-05-03  智慧手錶   3   8476.58  25429.74  轉帳    現金    加急處理    1
#       ORD0164  2023-10-16  平板     4   8922.88  35691.52  轉帳    已出貨   需揀貨     1
#       ORD0166  2023-02-07  手機     1   3486.42  3486.42   信用卡   現金    贈品包裝    1
# 鄧紫棋   ORD0010  2023-07-11  手機     5   9891.03  49455.15  電子支付  退貨    加急處理    1
#       ORD0019  2023-01-11  耳機     6   9074.87  54449.22  信用卡   已出貨   加急處理    1
#       ORD0025  2023-01-04  筆記型電腦  9   7892.32  71030.88  轉帳    處理中   加急處理    1
#       ORD0049  2023-04-08  滑鼠     7   4423.43  30964.01  電子支付  已出貨   急件      1
#       ORD0085  2023-01-08  打印機    8   3270.44  26163.52  信用卡   已出貨   贈品包裝    1
#       ORD0092  2023-04-20  耳機     1   8031.10  8031.10   電子支付  已出貨   急件      1
#       ORD0116  2023-01-30  智慧手錶   5   4569.89  22849.45  信用卡   已取消   急件      1
#       ORD0117  2023-01-26  智慧手錶   10  7435.13  74351.30  轉帳    現金    贈品包裝    1
#       ORD0142  2023-12-03  平板     7   9689.26  67824.82  轉帳    現金    加急處理    1
#       ORD0144  2023-10-17  相機     7   8273.79  57916.53  現金    已取消           1
#       ORD0149  2023-12-09  耳機     4   3415.56  13662.24  轉帳    退貨            1
#       ORD0160  2023-02-07  智慧手錶   8   2636.56  21092.48  轉帳    已出貨   贈品包裝    1
#       ORD0162  2023-08-23  打印機    8   8180.49  65443.92  信用卡   現金    加急處理    1
#       ORD0173  2023-02-05  手機     5   7215.48  36077.40  信用卡   處理中   需揀貨     1
#       ORD0191  2023-03-10  滑鼠     4   2733.26  10933.04  信用卡   退貨    加急處理    1
#       ORD0196  2023-03-21  智慧手錶   8   2947.46  23579.68  現金    現金    加急處理    1
#       ORD0199  2023-11-06  滑鼠     2   9789.46  19578.92  電子支付  已取消   急件      1
# 陳大文   ORD0007  2023-07-24  顯示器    3   5108.16  15324.48  現金    處理中   加急處理    1
#       ORD0036  2023-05-02  平板     5   7245.55  36227.75  電子支付  處理中   需揀貨     1
#       ORD0073  2023-08-05  智慧手錶   2   1243.92  2487.84   現金    現金    贈品包裝    1
#       ORD0084  2023-10-04  智慧手錶   1   8487.32  8487.32   轉帳    已出貨           1
#       ORD0087  2023-05-02  智慧手錶   3   1174.45  3523.35   現金    處理中   急件      1
#       ORD0112  2023-10-24  筆記型電腦  3   1231.11  3693.33   轉帳    處理中   急件      1
#       ORD0114  2023-02-01  打印機    3   7096.13  21288.39  信用卡   已取消   贈品包裝    1
#       ORD0125  2023-02-11  智慧手錶   1   2089.50  2089.50   電子支付  現金            1
#       ORD0131  2023-05-01  滑鼠     4   5553.65  22214.60  轉帳    現金            1
#       ORD0133  2023-03-03  滑鼠     3   8646.18  25938.54  轉帳    已取消   需揀貨     1
#       ORD0156  2023-11-27  鍵盤     5   6492.99  32464.95  現金    處理中   需揀貨     1
#       ORD0161  2023-01-05  智慧手錶   6   2909.08  17454.48  電子支付  已出貨   需揀貨     1
#       ORD0170  2023-05-16  智慧手錶   2   7480.67  14961.34  電子支付  現金    贈品包裝    1
#       ORD0172  2023-06-28  鍵盤     1   7823.48  7823.48   轉帳    處理中   需揀貨     1
#       ORD0192  2023-05-16  顯示器    7   2075.99  14531.93  現金    現金            1
#       ORD0193  2023-03-01  滑鼠     8   5822.78  46582.24  信用卡   已出貨   贈品包裝    1
#       ORD0197  2023-05-20  筆記型電腦  5   5357.79  26788.95  轉帳    退貨    贈品包裝    1

# %%
results = df.groupby(by=['客戶名稱'])

results = results[['產品' , '付款方式']].value_counts()

print(results.to_string())
# Out:
# 客戶名稱  產品     付款方式
# 劉德華   鍵盤     現金      3
#       手機     現金      2
#       智慧手錶   信用卡     2
#       平板     電子支付    1
#       打印機    現金      1
#              轉帳      1
#       智慧手錶   現金      1
#       滑鼠     轉帳      1
#       耳機     信用卡     1
#              現金      1
#       鍵盤     信用卡     1
# 周杰倫   平板     信用卡     2
#       打印機    電子支付    2
#       智慧手錶   現金      2
#       顯示器    現金      2
#       智慧手錶   轉帳      1
#       滑鼠     電子支付    1
#       相機     電子支付    1
#       耳機     現金      1
# 張大偉   平板     轉帳      2
#       智慧手錶   信用卡     2
#              現金      2
#       耳機     現金      2
#       手機     信用卡     1
#       滑鼠     現金      1
#              電子支付    1
#       相機     現金      1
#              轉帳      1
#       筆記型電腦  信用卡     1
#              轉帳      1
#       耳機     信用卡     1
# 李小華   智慧手錶   信用卡     3
#              轉帳      3
#              現金      2
#       滑鼠     電子支付    2
#       鍵盤     現金      2
#       手機     現金      1
#       打印機    現金      1
#              電子支付    1
#       智慧手錶   電子支付    1
#       滑鼠     現金      1
#       相機     信用卡     1
#              現金      1
#       筆記型電腦  轉帳      1
#              電子支付    1
#       耳機     現金      1
#       顯示器    信用卡     1
#              電子支付    1
# 林小美   平板     現金      2
#       手機     現金      2
#       智慧手錶   轉帳      2
#       滑鼠     轉帳      2
#       平板     信用卡     1
#       手機     信用卡     1
#       打印機    現金      1
#       智慧手錶   現金      1
#              電子支付    1
#       滑鼠     現金      1
#              電子支付    1
#       相機     現金      1
#       筆記型電腦  信用卡     1
#              現金      1
#       耳機     現金      1
#       鍵盤     電子支付    1
#       顯示器    電子支付    1
# 王小明   智慧手錶   現金      2
#       耳機     信用卡     2
#       平板     轉帳      1
#       智慧手錶   信用卡     1
#       相機     信用卡     1
#              現金      1
#       筆記型電腦  信用卡     1
#              現金      1
#              電子支付    1
#       鍵盤     信用卡     1
#              電子支付    1
#       顯示器    現金      1
#              電子支付    1
# 蔡依林   平板     信用卡     1
#              電子支付    1
#       打印機    現金      1
#              轉帳      1
#              電子支付    1
#       智慧手錶   信用卡     1
#              現金      1
#              電子支付    1
#       滑鼠     現金      1
#              轉帳      1
#              電子支付    1
#       筆記型電腦  電子支付    1
#       耳機     現金      1
#              電子支付    1
#       鍵盤     現金      1
#       顯示器    現金      1
# 遺失客戶  手機     現金      2
#       智慧手錶   現金      2
#       筆記型電腦  轉帳      2
#       平板     轉帳      1
#       手機     轉帳      1
#       打印機    轉帳      1
#       智慧手錶   信用卡     1
#              轉帳      1
#       滑鼠     信用卡     1
#              轉帳      1
#       相機     現金      1
#              轉帳      1
#       耳機     現金      1
#       鍵盤     現金      1
#              電子支付    1
#       顯示器    信用卡     1
# 郭富城   鍵盤     現金      3
#       手機     信用卡     2
#       智慧手錶   轉帳      2
#       滑鼠     現金      2
#       相機     現金      2
#       鍵盤     電子支付    2
#       平板     轉帳      1
#       打印機    轉帳      1
#       智慧手錶   電子支付    1
#       筆記型電腦  信用卡     1
#              轉帳      1
#              電子支付    1
#       耳機     信用卡     1
#              現金      1
#              電子支付    1
# 鄧紫棋   平板     轉帳      2
#       手機     信用卡     2
#       打印機    信用卡     2
#       智慧手錶   現金      2
#              轉帳      2
#       滑鼠     電子支付    2
#       手機     電子支付    1
#       打印機    現金      1
#       智慧手錶   信用卡     1
#       滑鼠     信用卡     1
#       相機     現金      1
#       筆記型電腦  轉帳      1
#       耳機     信用卡     1
#              現金      1
#              轉帳      1
#              電子支付    1
# 陳大文   智慧手錶   電子支付    3
#              現金      2
#       滑鼠     轉帳      2
#       筆記型電腦  轉帳      2
#       顯示器    現金      2
#       平板     電子支付    1
#       打印機    信用卡     1
#       智慧手錶   轉帳      1
#       滑鼠     信用卡     1
#       相機     信用卡     1
#       鍵盤     現金      1
#              轉帳      1

# %%
#客戶資料表 (df1),
df1 = pd.DataFrame({
    '客戶編號': [1, 2, 3, 4, 5, 7],
    '客戶名稱': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
    '地址': ['台北市中山區', '新北市板橋區', '台中市西區', '高雄市鼓山區', '台南市中西區', '桃園市中壢區'],
    '電話': ['02-12345678', '02-23456789', '04-34567890', '07-45678901', '06-56789012', '03-67890123'],
    '會員等級': ['金卡', '普通', '白金', '金卡', '普通', '白金']
})
df1.head(100)
# Out:
#    客戶編號     客戶名稱      地址           電話 會員等級
# 0     1    Alice  台北市中山區  02-12345678   金卡
# 1     2      Bob  新北市板橋區  02-23456789   普通
# 2     3  Charlie   台中市西區  04-34567890   白金
# 3     4    David  高雄市鼓山區  07-45678901   金卡
# 4     5      Eva  台南市中西區  06-56789012   普通
# 5     7    Frank  桃園市中壢區  03-67890123   白金

# %%
#訂單資料表 (df2),
df2 = pd.DataFrame({
    '訂單編號': ['ORD001', 'ORD002', 'ORD003', 'ORD004', 'ORD005', 'ORD006'],
    '客戶編號': [1, 2, 2, 6, 3, 7],  # 注意：客戶編號 6 不存在於 df1 中
    '訂單日期': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05', '2023-02-10'],
    '產品': ['筆記型電腦', '手機', '平板', '耳機', '鍵盤', '滑鼠'],
    '數量': [2, 1, 3, 5, 1, 4],
    '總價': [56000.00, 15000.00, 23000.00, 4500.00, 3200.00, 2800.00],
    '付款方式': ['信用卡', '現金', '轉帳', '電子支付', '信用卡', '現金'],
    '訂單狀態': ['已出貨', '處理中', '已取消', '已出貨', '退貨', '已出貨']
})
df2.head(100)
# Out:
#      訂單編號  客戶編號        訂單日期     產品  數量       總價  付款方式 訂單狀態
# 0  ORD001     1  2023-01-01  筆記型電腦   2  56000.0   信用卡  已出貨
# 1  ORD002     2  2023-01-02     手機   1  15000.0    現金  處理中
# 2  ORD003     2  2023-01-03     平板   3  23000.0    轉帳  已取消
# 3  ORD004     6  2023-01-04     耳機   5   4500.0  電子支付  已出貨
# 4  ORD005     3  2023-01-05     鍵盤   1   3200.0   信用卡   退貨
# 5  ORD006     7  2023-02-10     滑鼠   4   2800.0    現金  已出貨

# %%
#left join 
df = df2.merge(df1, on ='客戶編號',how="left")
df.head(100)
# Out:
#      訂單編號  客戶編號        訂單日期     產品  數量       總價  付款方式 訂單狀態     客戶名稱      地址  \
# 0  ORD001     1  2023-01-01  筆記型電腦   2  56000.0   信用卡  已出貨    Alice  台北市中山區
# 1  ORD002     2  2023-01-02     手機   1  15000.0    現金  處理中      Bob  新北市板橋區
# 2  ORD003     2  2023-01-03     平板   3  23000.0    轉帳  已取消      Bob  新北市板橋區
# 3  ORD004     6  2023-01-04     耳機   5   4500.0  電子支付  已出貨      NaN     NaN
# 4  ORD005     3  2023-01-05     鍵盤   1   3200.0   信用卡   退貨  Charlie   台中市西區
# 5  ORD006     7  2023-02-10     滑鼠   4   2800.0    現金  已出貨    Frank  桃園市中壢區
#
#             電話 會員等級
# 0  02-12345678   金卡
# 1  02-23456789   普通
# 2  02-23456789   普通
# 3          NaN  NaN
# 4  04-34567890   白金
# 5  03-67890123   白金

# %%
#inner join (只會合併兩邊都有的值)
df = df2.merge(df1, on ='客戶編號')
df.head(100)
# Out:
#      訂單編號  客戶編號        訂單日期     產品  數量       總價 付款方式 訂單狀態     客戶名稱      地址  \
# 0  ORD001     1  2023-01-01  筆記型電腦   2  56000.0  信用卡  已出貨    Alice  台北市中山區
# 1  ORD002     2  2023-01-02     手機   1  15000.0   現金  處理中      Bob  新北市板橋區
# 2  ORD003     2  2023-01-03     平板   3  23000.0   轉帳  已取消      Bob  新北市板橋區
# 3  ORD005     3  2023-01-05     鍵盤   1   3200.0  信用卡   退貨  Charlie   台中市西區
# 4  ORD006     7  2023-02-10     滑鼠   4   2800.0   現金  已出貨    Frank  桃園市中壢區
#
#             電話 會員等級
# 0  02-12345678   金卡
# 1  02-23456789   普通
# 2  02-23456789   普通
# 3  04-34567890   白金
# 4  03-67890123   白金

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# 固定隨機種子，確保每次產生的隨機資料一致
np.random.seed(42)
random.seed(42)

# ------------------------------
# 1. 客戶資料表 (20 筆) - 使用真實姓名
# ------------------------------
customer_names = [
    "王小明", "陳大文", "李大同", "林志玲", "周杰倫",
    "吳彥祖", "徐若瑄", "蔡依林", "楊丞琳", "張學友",
    "劉德華", "郭富城", "張曼玉", "梁朝偉", "周潤發",
    "黎明", "鄧麗君", "葉倩文", "梅艷芳", "范冰冰"
]

df_customers = pd.DataFrame({
    '客戶編號': list(range(1, 21)),
    '客戶名稱': customer_names,
    '地址': np.random.choice(['台北市', '新北市', '台中市', '高雄市', '台南市'], 20).tolist(),
    '會員等級': np.random.choice(['金卡', '普通', '白金'], 20).tolist()
})

# ------------------------------
# 2. 訂單資料表 (20 筆)
# ------------------------------
order_ids = [f"ORD{str(i).zfill(3)}" for i in range(1, 21)]
order_customer_ids = np.random.randint(1, 21, 20)  # 客戶編號從 1 到 20

# 訂單日期隨機介於 2023-01-01 與 2023-04-30
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 4, 30)
days_range = (end_date - start_date).days
order_dates = [(start_date + timedelta(days=random.randint(0, days_range))).strftime("%Y-%m-%d")
               for _ in range(20)]
products = ['筆記型電腦', '手機', '平板', '耳機', '鍵盤', '滑鼠', '顯示器']
order_products = [random.choice(products) for _ in range(20)]
order_quantities = np.random.randint(1, 6, 20)  # 數量 1 到 5

# 每筆訂單的單價隨機 10,000 到 60,000 之間，總價 = 數量 * 單價
unit_prices = [round(random.uniform(10000, 60000), 2) for _ in range(20)]
order_total_prices = [round(q * p, 2) for q, p in zip(order_quantities, unit_prices)]

df_orders = pd.DataFrame({
    '訂單編號': order_ids,
    '客戶編號': order_customer_ids,
    '訂單日期': pd.to_datetime(order_dates),
    '產品': order_products,
    '數量': order_quantities,
    '總價': order_total_prices
})

# ------------------------------
# 3. 付款資料表 (20 筆)
# ------------------------------
# 假設每筆訂單均有對應的付款記錄，付款日期為訂單日期後 1~10 天，付款金額與訂單總價一致
payment_ids = [f"PAY{str(i).zfill(3)}" for i in range(1, 21)]
payment_dates = [(datetime.strptime(date, "%Y-%m-%d") + timedelta(days=random.randint(1, 10))).strftime("%Y-%m-%d")
                 for date in order_dates]
payment_amounts = order_total_prices.copy()  # 一次全額付款

df_payments = pd.DataFrame({
    '付款編號': payment_ids,
    '訂單編號': order_ids,
    '付款日期': pd.to_datetime(payment_dates),
    '付款金額': payment_amounts
})

df_orders.head(100)

# 1. 請以 df_orders 為主 ， 合併  df_payments df_customers

# 2. 並以「客戶編號」與「客戶名稱」分組，計算每位客戶的

    # a. 總訂單數
    # b. 總訂單金額
    # c. 平均付款延遲天數


# 3. 分組結果新增一個名為「VIP」的欄位，「總訂單金額」大於 300000 且「總訂單數」大於 2，則標記為「VIP」否則普通

# 4. 過濾出會員等級為「白金」或「金卡」的客戶

# 5. 「總訂單金額」對結果進行遞減排序
# Out:
#       訂單編號  客戶編號       訂單日期     產品  數量         總價
# 0   ORD001     7 2023-03-23     手機   4  201163.84
# 1   ORD002     9 2023-01-15     手機   2   89813.94
# 2   ORD003     7 2023-01-04     鍵盤   2   54025.06
# 3   ORD004    18 2023-04-05     鍵盤   4   71095.88
# 4   ORD005     4 2023-02-05  筆記型電腦   5  289303.25
# 5   ORD006    14 2023-02-01     鍵盤   2   53659.46
# 6   ORD007    18 2023-01-29     手機   2   29274.58
# 7   ORD008     9 2023-01-18     滑鼠   4   59343.28
# 8   ORD009     2 2023-04-05     滑鼠   2  104749.44
# 9   ORD010    20 2023-01-14     滑鼠   2   80372.60
# 10  ORD011    15 2023-03-28     鍵盤   4  201425.64
# 11  ORD012     7 2023-04-05     耳機   4  185946.36
# 12  ORD013    12 2023-04-25     手機   1   36811.40
# 13  ORD014     8 2023-03-11     耳機   5  293278.95
# 14  ORD015    15 2023-01-12     鍵盤   5  144633.60
# 15  ORD016     3 2023-03-17     平板   2   75204.06
# 16  ORD017    14 2023-02-24    顯示器   5  257351.15
# 17  ORD018    17 2023-01-05    顯示器   2   81851.98
# 18  ORD019     4 2023-01-04  筆記型電腦   1   53085.35
# 19  ORD020    18 2023-01-12    顯示器   4  155470.44

# %%
#1
df = df_customers
df.head(20)
#df = df_customers.merge(df_orders, on ='客戶編號')
#df.head(100)
# Out:
#     客戶編號 客戶名稱   地址 會員等級
# 0      1  王小明  高雄市   普通
# 1      2  陳大文  台南市   普通
# 2      3  李大同  台中市   金卡
# 3      4  林志玲  台南市   金卡
# 4      5  周杰倫  台南市   金卡
# 5      6  吳彥祖  新北市   白金
# 6      7  徐若瑄  台中市   白金
# 7      8  蔡依林  台中市   白金
# 8      9  楊丞琳  台中市   普通
# 9     10  張學友  台南市   白金
# 10    11  劉德華  高雄市   普通
# 11    12  郭富城  台中市   普通
# 12    13  張曼玉  台南市   白金
# 13    14  梁朝偉  新北市   普通
# 14    15  周潤發  高雄市   白金
# 15    16   黎明  新北市   白金
# 16    17  鄧麗君  高雄市   金卡
# 17    18  葉倩文  台南市   白金
# 18    19  梅艷芳  台北市   金卡
# 19    20  范冰冰  高雄市   白金

# %%
#2
df = df_orders
df.head(20)
# Out:
#       訂單編號  客戶編號       訂單日期     產品  數量         總價
# 0   ORD001     7 2023-03-23     手機   4  201163.84
# 1   ORD002     9 2023-01-15     手機   2   89813.94
# 2   ORD003     7 2023-01-04     鍵盤   2   54025.06
# 3   ORD004    18 2023-04-05     鍵盤   4   71095.88
# 4   ORD005     4 2023-02-05  筆記型電腦   5  289303.25
# 5   ORD006    14 2023-02-01     鍵盤   2   53659.46
# 6   ORD007    18 2023-01-29     手機   2   29274.58
# 7   ORD008     9 2023-01-18     滑鼠   4   59343.28
# 8   ORD009     2 2023-04-05     滑鼠   2  104749.44
# 9   ORD010    20 2023-01-14     滑鼠   2   80372.60
# 10  ORD011    15 2023-03-28     鍵盤   4  201425.64
# 11  ORD012     7 2023-04-05     耳機   4  185946.36
# 12  ORD013    12 2023-04-25     手機   1   36811.40
# 13  ORD014     8 2023-03-11     耳機   5  293278.95
# 14  ORD015    15 2023-01-12     鍵盤   5  144633.60
# 15  ORD016     3 2023-03-17     平板   2   75204.06
# 16  ORD017    14 2023-02-24    顯示器   5  257351.15
# 17  ORD018    17 2023-01-05    顯示器   2   81851.98
# 18  ORD019     4 2023-01-04  筆記型電腦   1   53085.35
# 19  ORD020    18 2023-01-12    顯示器   4  155470.44

# %%
#3
df = df_payments
df.head(20)
# Out:
#       付款編號    訂單編號       付款日期       付款金額
# 0   PAY001  ORD001 2023-03-25  201163.84
# 1   PAY002  ORD002 2023-01-16   89813.94
# 2   PAY003  ORD003 2023-01-08   54025.06
# 3   PAY004  ORD004 2023-04-10   71095.88
# 4   PAY005  ORD005 2023-02-07  289303.25
# 5   PAY006  ORD006 2023-02-05   53659.46
# 6   PAY007  ORD007 2023-01-31   29274.58
# 7   PAY008  ORD008 2023-01-25   59343.28
# 8   PAY009  ORD009 2023-04-10  104749.44
# 9   PAY010  ORD010 2023-01-22   80372.60
# 10  PAY011  ORD011 2023-04-03  201425.64
# 11  PAY012  ORD012 2023-04-08  185946.36
# 12  PAY013  ORD013 2023-05-01   36811.40
# 13  PAY014  ORD014 2023-03-17  293278.95
# 14  PAY015  ORD015 2023-01-16  144633.60
# 15  PAY016  ORD016 2023-03-22   75204.06
# 16  PAY017  ORD017 2023-02-26  257351.15
# 17  PAY018  ORD018 2023-01-15   81851.98
# 18  PAY019  ORD019 2023-01-07   53085.35
# 19  PAY020  ORD020 2023-01-21  155470.44

# %%
#1
df = df_orders.merge(df_payments, on ='訂單編號',how="left")
df = df.merge(df_customers, on ='客戶編號',how="left")

df.head(20)
# Out:
#       訂單編號  客戶編號       訂單日期     產品  數量         總價    付款編號       付款日期  \
# 0   ORD001     7 2023-03-23     手機   4  201163.84  PAY001 2023-03-25
# 1   ORD002     9 2023-01-15     手機   2   89813.94  PAY002 2023-01-16
# 2   ORD003     7 2023-01-04     鍵盤   2   54025.06  PAY003 2023-01-08
# 3   ORD004    18 2023-04-05     鍵盤   4   71095.88  PAY004 2023-04-10
# 4   ORD005     4 2023-02-05  筆記型電腦   5  289303.25  PAY005 2023-02-07
# 5   ORD006    14 2023-02-01     鍵盤   2   53659.46  PAY006 2023-02-05
# 6   ORD007    18 2023-01-29     手機   2   29274.58  PAY007 2023-01-31
# 7   ORD008     9 2023-01-18     滑鼠   4   59343.28  PAY008 2023-01-25
# 8   ORD009     2 2023-04-05     滑鼠   2  104749.44  PAY009 2023-04-10
# 9   ORD010    20 2023-01-14     滑鼠   2   80372.60  PAY010 2023-01-22
# 10  ORD011    15 2023-03-28     鍵盤   4  201425.64  PAY011 2023-04-03
# 11  ORD012     7 2023-04-05     耳機   4  185946.36  PAY012 2023-04-08
# 12  ORD013    12 2023-04-25     手機   1   36811.40  PAY013 2023-05-01
# 13  ORD014     8 2023-03-11     耳機   5  293278.95  PAY014 2023-03-17
# 14  ORD015    15 2023-01-12     鍵盤   5  144633.60  PAY015 2023-01-16
# 15  ORD016     3 2023-03-17     平板   2   75204.06  PAY016 2023-03-22
# 16  ORD017    14 2023-02-24    顯示器   5  257351.15  PAY017 2023-02-26
# 17  ORD018    17 2023-01-05    顯示器   2   81851.98  PAY018 2023-01-15
# 18  ORD019     4 2023-01-04  筆記型電腦   1   53085.35  PAY019 2023-01-07
# 19  ORD020    18 2023-01-12    顯示器   4  155470.44  PAY020 2023-01-21
#
#          付款金額 客戶名稱   地址 會員等級
# 0   201163.84  徐若瑄  台中市   白金
# 1    89813.94  楊丞琳  台中市   普通
# 2    54025.06  徐若瑄  台中市   白金
# 3    71095.88  葉倩文  台南市   白金
# 4   289303.25  林志玲  台南市   金卡
# 5    53659.46  梁朝偉  新北市   普通
# 6    29274.58  葉倩文  台南市   白金
# 7    59343.28  楊丞琳  台中市   普通
# 8   104749.44  陳大文  台南市   普通
# 9    80372.60  范冰冰  高雄市   白金
# 10  201425.64  周潤發  高雄市   白金
# 11  185946.36  徐若瑄  台中市   白金
# 12   36811.40  郭富城  台中市   普通
# 13  293278.95  蔡依林  台中市   白金
# 14  144633.60  周潤發  高雄市   白金
# 15   75204.06  李大同  台中市   金卡
# 16  257351.15  梁朝偉  新北市   普通
# 17   81851.98  鄧麗君  高雄市   金卡
# 18   53085.35  林志玲  台南市   金卡
# 19  155470.44  葉倩文  台南市   白金

# %%
#2 
df['平均付款延遲天數'] = df['付款日期'] - df['訂單日期']
df["總訂單數"] = df["數量"]
df["總訂單金額"] = df["總價"]
#df.head(20)
results = df.groupby(by=['客戶編號']).agg({
    "總訂單數":['sum'],
    "總訂單金額":['sum'],
    "平均付款延遲天數":['mean'],
})
#results["總訂單數"] = results["數量"]
#results["總訂單金額"] = results["總價"]
#results = results.drop(["數量","總價","平均付款延遲"], axis = "columns")
df = results
df.head(100000)
# Out:
#      總訂單數      總訂單金額         平均付款延遲天數
#       sum        sum             mean
# 客戶編號
# 2       2  104749.44  5 days 00:00:00
# 3       2   75204.06  5 days 00:00:00
# 4       6  342388.60  2 days 12:00:00
# 7      10  441135.26  3 days 00:00:00
# 8       5  293278.95  6 days 00:00:00
# 9       6  149157.22  4 days 00:00:00
# 12      1   36811.40  6 days 00:00:00
# 14      7  311010.61  3 days 00:00:00
# 15      9  346059.24  5 days 00:00:00
# 17      2   81851.98 10 days 00:00:00
# 18     10  255840.90  5 days 08:00:00
# 20      2   80372.60  8 days 00:00:00

# %%
#3
df['VIP'] = df.apply(lambda row : "VIP" if (row["總訂單金額"] > 300000 and row["總訂單數"] >2) else" 普通" ,axis = 1)
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 2
#       1 #3
# ----> 2 df['VIP'] = df.apply(lambda row : "VIP" if (row["總訂單金額"] > 300000 and row["總訂單數"] >2) else" 普通" ,axis = 1)
#       3 df.head(20)
#
# File ~\anaconda3\envs\jupyter_env\lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\envs\jupyter_env\lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~\anaconda3\envs\jupyter_env\lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~\anaconda3\envs\jupyter_env\lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[99], line 2, in <lambda>(row)
#       1 #3
# ----> 2 df['VIP'] = df.apply(lambda row : "VIP" if (row["總訂單金額"] > 300000 and row["總訂單數"] >2) else" 普通" ,axis = 1)
#       3 df.head(20)
#
# File ~\anaconda3\envs\jupyter_env\lib\site-packages\pandas\core\generic.py:1577, in NDFrame.__nonzero__(self)
#    1575 @final
#    1576 def __nonzero__(self) -> NoReturn:
# -> 1577     raise ValueError(
#    1578         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
