# %%
#UBIKE 網站
# https://www.youbike.com.tw/region/main/stations/list/

import requests
import pandas as pd

url = "https://apis.youbike.com.tw/json/area-all.json"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
data[0]
# Out:
# {'_id': '5cb57c0c083e7b18a52ba5f2',
#  'country_code': '00',
#  'area_code': '00',
#  'area_english': 'taipei',
#  'bike_code': 'A/5001',
#  'station_start': '0001',
#  'station_end': '0999',
#  'domain': 'https://taipei.youbike.com.tw',
#  'is_open': 1,
#  'is_bind': 1,
#  'register_card': [{'card_type': 1,
#    'img': '/images/15937428565efe96085b11c.png',
#    'show': [],
#    'name_en': 'EasyCard',
#    'name_tw': '悠遊卡',
#    'name_cn': ''},
#   {'card_type': 2,
#    'img': '/images/15937428395efe95f7d99b4.png',
#    'show': [],
#    'name_en': 'iPASS',
#    'name_tw': '一卡通',
#    'name_cn': ''},
#   {'card_type': 20,
#    'img': '/images/15556659945cb9944a40908.png',
#    'show': [],
#    'name_en': 'APP',
#    'name_tw': 'APP掃碼',
#    'name_cn': ''},
#   {'card_type': 22,
#    'img': '/images/16171590436063e3832d1a2.jpg',
#    'show': [],
#    'name_en': 'LINE Pay',
#    'name_tw': 'LINE Pay',
#    'name_cn': ''},
#   {'card_type': 23,
#    'img': '/images/1620203769609258f939358.png',
#    'show': [],
#    'name_en': 'Easy Wallet',
#    'name_tw': '悠遊付',
#    'name_cn': ''}],
#  'contact_phone': {'tw': '市民熱線1999轉5855 / 02-89785511(付費)',
#   'en': '1999#5855 / 02-8978-5511'},
#  'contact_mail': 'service-taipei@youbike.com.tw',
#  'ad_phone': '--',
#  'ad_mail': 'ChiayiHsieh@youbike.com.tw',
#  'lat': '25.047924',
#  'lng': '121.517081',
#  'ride_count': 203063948,
#  'member_card_count': 15860563,
#  'visit_count': 34092713,
#  'sort': 1,
#  'updated_at': '2025-06-19 21:40:39',
#  'created_at': '2019-04-16 14:54:04',
#  'type': 1,
#  'area_district': '台北市',
#  'service_phone': '02-8978-8822',
#  'contact_phone_2': {'tw': '02-8978-8822', 'en': '1999 / 02-8978-8822'},
#  'ride_count2': 184467609,
#  'lat2': '25.0173453',
#  'lng2': '121.5375631',
#  'bike_type': ['2', '3'],
#  'area_code_2': '01',
#  'country_name_tw': '台灣',
#  'country_name_cn': '',
#  'country_name_en': 'Taiwan',
#  'area_name_tw': '台北市',
#  'area_name_cn': '',
#  'area_name_en': 'Taipei City'}

# %%
df = pd.DataFrame(data)

df.head(100)
# Out:
#                          _id country_code area_code area_english bike_code  \
# 0   5cb57c0c083e7b18a52ba5f2           00        00       taipei    A/5001
# 1   5cb57c0c083e7b18a52ba5f4           00        05         ntpc    F/5002
# 2   5cb57c0c083e7b18a52ba5f5           00        07         tycg    H/5003
# 3   62ac48d85fc310282536ff13           00        0B      hsinchu    Y/5005
# 4   5b4330e22ef72c09c204b382           00        09         hccg    J/5004
# 5   5cb57c0c083e7b18a52ba5f9           00        10         sipa    S/5082
# 6   5cb57c0c083e7b18a52ba5f6           00        0A       miaoli    K/5007
# 7   5cb57c0c083e7b18a52ba5f3           00        01     taichung    B/5006
# 8   6674e508cd0251893008d7f4           00        11         cyhg    Y/5011
# 9   5fc056a9083e7b29257954e5           00        08       chiayi    Y/5010
# 10  63f426c7e7c85057523d1b42           00        13       tainan    Y/5013
# 11  5ec5dcfa1b99457a7a6247c3           00        12    Kaohsiung    Y/5012
# 12  63c4af5eea9cb236dc2a5cc4           00        14         pthg    Y/5014
# 13  675109adb4fed7138200d643           00        15      taitung    Y/5015
#
#    station_start station_end                                    domain  \
# 0           0001        0999             https://taipei.youbike.com.tw
# 1           1001        1999               https://ntpc.youbike.com.tw
# 2           2001        2999               https://tycg.youbike.com.tw
# 3        0501001     0599999   https://www.youbike.com.tw/region/main/
# 4           6101        6299               https://hccg.youbike.com.tw
# 5           9601        9615               https://sipa.youbike.com.tw
# 6           6601        6999             https://miaoli.youbike.com.tw
# 7           3001        3999                  https://i.youbike.com.tw
# 8        1101001     1199999    https://www.youbike.com.tw/region/cyhg
# 9           8001        8888             https://chiayi.youbike.com.tw
# 10       1301001     1399999  https://www.youbike.com.tw/region/tainan
# 11          5001        5999                https://kcg.youbike.com.tw
# 12       1401001     1499999   https://www.youbike.com.tw/region/pthg/
# 13       1501001     1599999       https://taitung.youbike.com.tw/home
#
#     is_open  is_bind  ...                lat2                lng2 bike_type  \
# 0         1        1  ...          25.0173453         121.5375631    [2, 3]
# 1         1        1  ...    25.0215339197085   121.4568090197085    [2, 3]
# 2         1        1  ...           24.953671          121.225783    [2, 3]
# 3         1        1  ...     24.826917615712     121.01290295049    [2, 3]
# 4         1        1  ...           24.801815          120.971459    [2, 3]
# 5         1        1  ...           24.781830          121.005074    [2, 3]
# 6         1        1  ...          24.5648599         120.8185503    [2, 3]
# 7         1        1  ...           24.154712          120.664265    [2, 3]
# 8         1        1  ...   23.45923583240034  120.29279014502468    [2, 3]
# 9         1        1  ...          23.4797837         120.4397206    [2, 3]
# 10        1        1  ...      22.99230083082     120.18509419659    [2, 3]
# 11        1        1  ...           22.631442          120.301890    [2, 3]
# 12        1        1  ...     22.683036253664     120.48790854724    [2, 3]
# 13        1        1  ...  22.755711056126138  121.15035332587574    [2, 3]
#
#    area_code_2 country_name_tw country_name_cn country_name_en  area_name_tw  \
# 0           01              台灣                          Taiwan           台北市
# 1           02              台灣                          Taiwan           新北市
# 2           03              台灣                          Taiwan           桃園市
# 3           05              台灣                          Taiwan           新竹縣
# 4           04              台灣                          Taiwan           新竹市
# 5           82              台灣                          Taiwan      新竹科學工業園區
# 6           07              台灣                          Taiwan           苗栗縣
# 7           06              台灣                          Taiwan           台中市
# 8           11              台灣                          Taiwan           嘉義縣
# 9           10              台灣                          Taiwan           嘉義市
# 10          13              台灣                          Taiwan           臺南市
# 11          12              台灣                          Taiwan           高雄市
# 12          14              台灣                          Taiwan           屏東縣
# 13          15              台灣                          Taiwan           臺東縣
#
#     area_name_cn          area_name_en
# 0                          Taipei City
# 1                      New Taipei City
# 2                         Taoyuan City
# 3                       Hsinchu County
# 4                         Hsinchu City
# 5                 Hsinchu Science Park
# 6                        Miaoli County
# 7                        Taichung City
# 8                        Chiayi County
# 9                          Chiayi City
# 10                         Tainan City
# 11                      Kaohsiung City
# 12                     Pingtung County
# 13                      Taitung County
#
# [14 rows x 38 columns]

# %%
city_code = df[["area_code","area_code_2","area_english","area_name_tw","is_open","register_card","station_start","station_end"]]
city_code.head(100)
# Out:
#    area_code area_code_2 area_english area_name_tw  is_open  \
# 0         00          01       taipei          台北市        1
# 1         05          02         ntpc          新北市        1
# 2         07          03         tycg          桃園市        1
# 3         0B          05      hsinchu          新竹縣        1
# 4         09          04         hccg          新竹市        1
# 5         10          82         sipa     新竹科學工業園區        1
# 6         0A          07       miaoli          苗栗縣        1
# 7         01          06     taichung          台中市        1
# 8         11          11         cyhg          嘉義縣        1
# 9         08          10       chiayi          嘉義市        1
# 10        13          13       tainan          臺南市        1
# 11        12          12    Kaohsiung          高雄市        1
# 12        14          14         pthg          屏東縣        1
# 13        15          15      taitung          臺東縣        1
#
#                                         register_card station_start  \
# 0   [{'card_type': 1, 'img': '/images/15937428565e...          0001
# 1   [{'card_type': 1, 'img': '/images/15937428565e...          1001
# 2   [{'card_type': 1, 'img': '/images/15937428565e...          2001
# 3   [{'card_type': 1, 'img': '/images/15937428565e...       0501001
# 4   [{'card_type': 1, 'img': '/images/15937428565e...          6101
# 5   [{'card_type': 1, 'img': '/images/15937428565e...          9601
# 6   [{'card_type': 1, 'img': '/images/15937428565e...          6601
# 7   [{'card_type': 1, 'img': '/images/15937428565e...          3001
# 8   [{'card_type': 1, 'img': '/images/15937428565e...       1101001
# 9   [{'card_type': 1, 'img': '/images/15937428565e...          8001
# 10  [{'card_type': 1, 'img': '/images/15937428565e...       1301001
# 11  [{'card_type': 1, 'img': '/images/15937428565e...          5001
# 12  [{'card_type': 1, 'img': '/images/15937428565e...       1401001
# 13  [{'card_type': 1, 'img': '/images/15937428565e...       1501001
#
#    station_end
# 0         0999
# 1         1999
# 2         2999
# 3      0599999
# 4         6299
# 5         9615
# 6         6999
# 7         3999
# 8      1199999
# 9         8888
# 10     1399999
# 11        5999
# 12     1499999
# 13     1599999

# %%
print(city_code["area_name_tw"].is_unique)
print(city_code["area_code"].is_unique)
print(city_code["area_code_2"].is_unique)
# Out:
# True
# True
# True

# %%
city_code = city_code.sort_values(by = ["area_code_2"])

city_code
# Out:
#    area_code area_code_2 area_english area_name_tw  is_open  \
# 0         00          01       taipei          台北市        1
# 1         05          02         ntpc          新北市        1
# 2         07          03         tycg          桃園市        1
# 4         09          04         hccg          新竹市        1
# 3         0B          05      hsinchu          新竹縣        1
# 7         01          06     taichung          台中市        1
# 6         0A          07       miaoli          苗栗縣        1
# 9         08          10       chiayi          嘉義市        1
# 8         11          11         cyhg          嘉義縣        1
# 11        12          12    Kaohsiung          高雄市        1
# 10        13          13       tainan          臺南市        1
# 12        14          14         pthg          屏東縣        1
# 13        15          15      taitung          臺東縣        1
# 5         10          82         sipa     新竹科學工業園區        1
#
#                                         register_card station_start  \
# 0   [{'card_type': 1, 'img': '/images/15937428565e...          0001
# 1   [{'card_type': 1, 'img': '/images/15937428565e...          1001
# 2   [{'card_type': 1, 'img': '/images/15937428565e...          2001
# 4   [{'card_type': 1, 'img': '/images/15937428565e...          6101
# 3   [{'card_type': 1, 'img': '/images/15937428565e...       0501001
# 7   [{'card_type': 1, 'img': '/images/15937428565e...          3001
# 6   [{'card_type': 1, 'img': '/images/15937428565e...          6601
# 9   [{'card_type': 1, 'img': '/images/15937428565e...          8001
# 8   [{'card_type': 1, 'img': '/images/15937428565e...       1101001
# 11  [{'card_type': 1, 'img': '/images/15937428565e...          5001
# 10  [{'card_type': 1, 'img': '/images/15937428565e...       1301001
# 12  [{'card_type': 1, 'img': '/images/15937428565e...       1401001
# 13  [{'card_type': 1, 'img': '/images/15937428565e...       1501001
# 5   [{'card_type': 1, 'img': '/images/15937428565e...          9601
#
#    station_end
# 0         0999
# 1         1999
# 2         2999
# 4         6299
# 3      0599999
# 7         3999
# 6         6999
# 9         8888
# 8      1199999
# 11        5999
# 10     1399999
# 12     1499999
# 13     1599999
# 5         9615

# %%
register_card_df = df[["area_code","area_code_2","area_name_tw","register_card"]]
register_card_df.head(100)
# Out:
#    area_code area_code_2 area_name_tw  \
# 0         00          01          台北市
# 1         05          02          新北市
# 2         07          03          桃園市
# 3         0B          05          新竹縣
# 4         09          04          新竹市
# 5         10          82     新竹科學工業園區
# 6         0A          07          苗栗縣
# 7         01          06          台中市
# 8         11          11          嘉義縣
# 9         08          10          嘉義市
# 10        13          13          臺南市
# 11        12          12          高雄市
# 12        14          14          屏東縣
# 13        15          15          臺東縣
#
#                                         register_card
# 0   [{'card_type': 1, 'img': '/images/15937428565e...
# 1   [{'card_type': 1, 'img': '/images/15937428565e...
# 2   [{'card_type': 1, 'img': '/images/15937428565e...
# 3   [{'card_type': 1, 'img': '/images/15937428565e...
# 4   [{'card_type': 1, 'img': '/images/15937428565e...
# 5   [{'card_type': 1, 'img': '/images/15937428565e...
# 6   [{'card_type': 1, 'img': '/images/15937428565e...
# 7   [{'card_type': 1, 'img': '/images/15937428565e...
# 8   [{'card_type': 1, 'img': '/images/15937428565e...
# 9   [{'card_type': 1, 'img': '/images/15937428565e...
# 10  [{'card_type': 1, 'img': '/images/15937428565e...
# 11  [{'card_type': 1, 'img': '/images/15937428565e...
# 12  [{'card_type': 1, 'img': '/images/15937428565e...
# 13  [{'card_type': 1, 'img': '/images/15937428565e...

# %%
taipei_card = register_card_df[register_card_df["area_name_tw"] == "台北市"]
taipei_card =  taipei_card.iloc[0]
taipei_card = taipei_card["register_card"]
taipei_card
# Out:
# [{'card_type': 1,
#   'img': '/images/15937428565efe96085b11c.png',
#   'show': [],
#   'name_en': 'EasyCard',
#   'name_tw': '悠遊卡',
#   'name_cn': ''},
#  {'card_type': 2,
#   'img': '/images/15937428395efe95f7d99b4.png',
#   'show': [],
#   'name_en': 'iPASS',
#   'name_tw': '一卡通',
#   'name_cn': ''},
#  {'card_type': 20,
#   'img': '/images/15556659945cb9944a40908.png',
#   'show': [],
#   'name_en': 'APP',
#   'name_tw': 'APP掃碼',
#   'name_cn': ''},
#  {'card_type': 22,
#   'img': '/images/16171590436063e3832d1a2.jpg',
#   'show': [],
#   'name_en': 'LINE Pay',
#   'name_tw': 'LINE Pay',
#   'name_cn': ''},
#  {'card_type': 23,
#   'img': '/images/1620203769609258f939358.png',
#   'show': [],
#   'name_en': 'Easy Wallet',
#   'name_tw': '悠遊付',
#   'name_cn': ''}]

# %%
taipei_card  = pd.DataFrame(taipei_card ) 
taipei_card.head(10)
# Out:
#    card_type                                  img show      name_en   name_tw  \
# 0          1  /images/15937428565efe96085b11c.png   []     EasyCard       悠遊卡
# 1          2  /images/15937428395efe95f7d99b4.png   []        iPASS       一卡通
# 2         20  /images/15556659945cb9944a40908.png   []          APP     APP掃碼
# 3         22  /images/16171590436063e3832d1a2.jpg   []     LINE Pay  LINE Pay
# 4         23  /images/1620203769609258f939358.png   []  Easy Wallet       悠遊付
#
#   name_cn
# 0
# 1
# 2
# 3
# 4

# %%
area_name_tws = city_code["area_name_tw"].unique() 
print(area_name_tws)
# Out:
# ['台北市' '新北市' '桃園市' '新竹市' '新竹縣' '台中市' '苗栗縣' '嘉義市' '嘉義縣' '高雄市' '臺南市' '屏東縣'
#  '臺東縣' '新竹科學工業園區']

# %%
card_table = None

for area_name_tw in area_name_tws:
    city_register_card = register_card_df[register_card_df["area_name_tw"]==area_name_tw].iloc[0]["register_card"]
    city_register_card = pd.DataFrame(city_register_card)

    print(area_name_tw,city_register_card["name_tw"].unique())

    if card_table is None :
        card_table = city_register_card
    else:
        card_table.merge(city_register_card , on = "card_type",how = "left")

card_table.head(100)
# Out:
# 台北市 ['悠遊卡' '一卡通' 'APP掃碼' 'LINE Pay' '悠遊付']
# 新北市 ['悠遊卡' '一卡通' 'APP掃碼' 'LINE Pay']
# 桃園市 ['悠遊卡' '一卡通' 'APP掃碼' 'LINE Pay']
# 新竹市 ['悠遊卡' '一卡通' 'APP掃碼' 'LINE Pay']
# 新竹縣 ['悠遊卡' '一卡通']
# 台中市 ['悠遊卡' '一卡通' 'APP掃碼' 'LINE Pay']
# 苗栗縣 ['悠遊卡' '一卡通' 'APP掃碼' 'LINE Pay']
# 嘉義市 ['悠遊卡' '一卡通' 'APP掃碼' 'LINE Pay']
# 嘉義縣 ['悠遊卡' '一卡通' 'APP掃碼']
# 高雄市 ['悠遊卡' '一卡通' 'APP掃碼' 'LINE Pay']
# 臺南市 ['悠遊卡' '一卡通' 'APP掃碼']
# 屏東縣 ['悠遊卡' '一卡通' 'APP掃碼']
# 臺東縣 ['悠遊卡' '一卡通' 'APP掃碼']
# 新竹科學工業園區 ['悠遊卡' '一卡通' 'APP掃碼' 'LINE Pay']
#    card_type                                  img show      name_en   name_tw  \
# 0          1  /images/15937428565efe96085b11c.png   []     EasyCard       悠遊卡
# 1          2  /images/15937428395efe95f7d99b4.png   []        iPASS       一卡通
# 2         20  /images/15556659945cb9944a40908.png   []          APP     APP掃碼
# 3         22  /images/16171590436063e3832d1a2.jpg   []     LINE Pay  LINE Pay
# 4         23  /images/1620203769609258f939358.png   []  Easy Wallet       悠遊付
#
#   name_cn
# 0
# 1
# 2
# 3
# 4

# %%
#查詢各縣市 ubike 站點數量

headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36",
    "Referer": "https://www.youbike.com.tw/",
}

url = 'https://apis.youbike.com.tw/api/front/station/count'

response = requests.get(url , headers = headers)
#response = requests.get(url)

data = []

if response.status_code == 200:
    data = response.json()
    print(data)
    if data["retMsg"] == "查詢各縣市場站數量成功" :
        data = data["retVal"]
else:
    print(f"HTTP {response.status_code}:{response}")
data = pd.DataFrame(data)
data.head()
# Out:
# {'retCode': 1, 'retMsg': '查詢各縣市場站數量成功', 'retVal': [{'area_code': '0B', 'yb1': 0, 'yb2': 164, 'total': 164}, {'area_code': '0A', 'yb1': 0, 'yb2': 194, 'total': 194}, {'area_code': '00', 'yb1': 0, 'yb2': 1604, 'total': 1604}, {'area_code': '07', 'yb1': 0, 'yb2': 573, 'total': 573}, {'area_code': '10', 'yb1': 0, 'yb2': 41, 'total': 41}, {'area_code': '05', 'yb1': 0, 'yb2': 1443, 'total': 1443}, {'area_code': '13', 'yb1': 0, 'yb2': 605, 'total': 605}, {'area_code': '14', 'yb1': 0, 'yb2': 157, 'total': 157}, {'area_code': '11', 'yb1': 0, 'yb2': 130, 'total': 130}, {'area_code': '15', 'yb1': 0, 'yb2': 66, 'total': 66}, {'area_code': '12', 'yb1': 0, 'yb2': 1440, 'total': 1440}, {'area_code': '09', 'yb1': 0, 'yb2': 108, 'total': 108}, {'area_code': '0D', 'yb1': 68, 'yb2': 0, 'total': 68}, {'area_code': '01', 'yb1': 0, 'yb2': 1601, 'total': 1601}, {'area_code': '08', 'yb1': 0, 'yb2': 196, 'total': 196}]}
#   area_code  yb1   yb2  total
# 0        0B    0   164    164
# 1        0A    0   194    194
# 2        00    0  1604   1604
# 3        07    0   573    573
# 4        10    0    41     41

# %%
city_code = city_code.merge(data , on = "area_code",how = "left")

city_code.head(20)
# Out:
#    area_code area_code_2 area_english area_name_tw  is_open  \
# 0         00          01       taipei          台北市        1
# 1         05          02         ntpc          新北市        1
# 2         07          03         tycg          桃園市        1
# 3         09          04         hccg          新竹市        1
# 4         0B          05      hsinchu          新竹縣        1
# 5         01          06     taichung          台中市        1
# 6         0A          07       miaoli          苗栗縣        1
# 7         08          10       chiayi          嘉義市        1
# 8         11          11         cyhg          嘉義縣        1
# 9         12          12    Kaohsiung          高雄市        1
# 10        13          13       tainan          臺南市        1
# 11        14          14         pthg          屏東縣        1
# 12        15          15      taitung          臺東縣        1
# 13        10          82         sipa     新竹科學工業園區        1
#
#                                         register_card station_start  \
# 0   [{'card_type': 1, 'img': '/images/15937428565e...          0001
# 1   [{'card_type': 1, 'img': '/images/15937428565e...          1001
# 2   [{'card_type': 1, 'img': '/images/15937428565e...          2001
# 3   [{'card_type': 1, 'img': '/images/15937428565e...          6101
# 4   [{'card_type': 1, 'img': '/images/15937428565e...       0501001
# 5   [{'card_type': 1, 'img': '/images/15937428565e...          3001
# 6   [{'card_type': 1, 'img': '/images/15937428565e...          6601
# 7   [{'card_type': 1, 'img': '/images/15937428565e...          8001
# 8   [{'card_type': 1, 'img': '/images/15937428565e...       1101001
# 9   [{'card_type': 1, 'img': '/images/15937428565e...          5001
# 10  [{'card_type': 1, 'img': '/images/15937428565e...       1301001
# 11  [{'card_type': 1, 'img': '/images/15937428565e...       1401001
# 12  [{'card_type': 1, 'img': '/images/15937428565e...       1501001
# 13  [{'card_type': 1, 'img': '/images/15937428565e...          9601
#
#    station_end  yb1   yb2  total
# 0         0999    0  1604   1604
# 1         1999    0  1443   1443
# 2         2999    0   573    573
# 3         6299    0   108    108
# 4      0599999    0   164    164
# 5         3999    0  1601   1601
# 6         6999    0   194    194
# 7         8888    0   196    196
# 8      1199999    0   130    130
# 9         5999    0  1440   1440
# 10     1399999    0   605    605
# 11     1499999    0   157    157
# 12     1599999    0    66     66
# 13        9615    0    41     41

# %%
# 查詢全台所有 ubile 站點

headers = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36",
    "Referer": "https://www.youbike.com.tw/",
}

url = 'https://apis.youbike.com.tw/json/station-yb2.json'

response = requests.get(url , headers=headers)

data = []

if response.status_code == 200:
    data = response.json()
   
else:
    print(f"HTTP {response.status_code}: {response}")

df = pd.DataFrame(data)
df.head()
